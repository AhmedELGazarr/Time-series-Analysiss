# %% [markdown]
# # Time series Analysis case study..

# %% [markdown]
# # IMPORTING OUR LIBARARIS

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # BREPROCESSING & CLEANING DATA..

# %%
# delete (الفئة: جميع الفئات)
df= pd.read_csv("multiTimeline.csv",skiprows=1)
df
# Out:
#        الشهر  diet: (في جميع أنحاء العالم)  gym: (في جميع أنحاء العالم)  \
# 0    2004-01                           100                           25
# 1    2004-02                            73                           21
# 2    2004-03                            66                           21
# 3    2004-04                            68                           19
# 4    2004-05                            71                           19
# ..       ...                           ...                          ...
# 216  2022-01                            35                           52
# 217  2022-02                            34                           50
# 218  2022-03                            33                           50
# 219  2022-04                            32                           47
# 220  2022-05                            32                           48
#
#      finance: (في جميع أنحاء العالم)
# 0                                 47
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   الشهر                            221 non-null    object
#  1   diet: (في جميع أنحاء العالم)     221 non-null    int64
#  2   gym: (في جميع أنحاء العالم)      221 non-null    int64
#  3   finance: (في جميع أنحاء العالم)  221 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.0+ KB

# %%
df
# Out:
#        الشهر  diet: (في جميع أنحاء العالم)  gym: (في جميع أنحاء العالم)  \
# 0    2004-01                           100                           25
# 1    2004-02                            73                           21
# 2    2004-03                            66                           21
# 3    2004-04                            68                           19
# 4    2004-05                            71                           19
# ..       ...                           ...                          ...
# 216  2022-01                            35                           52
# 217  2022-02                            34                           50
# 218  2022-03                            33                           50
# 219  2022-04                            32                           47
# 220  2022-05                            32                           48
#
#      finance: (في جميع أنحاء العالم)
# 0                                 47
# ...

# %%
#df.colums=["Month","diet","gym","finance"]
#change the colums name
df.rename({"الشهر":"month"},inplace =True, axis=1)
df.rename({"diet: (في جميع أنحاء العالم)":"diet"},inplace =True, axis=1)
df.rename({"gym: (في جميع أنحاء العالم)":"gym"},inplace =True, axis=1)
df.rename({"finance: (في جميع أنحاء العالم)":"finance"},inplace =True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    221 non-null    object
#  1   diet     221 non-null    int64
#  2   gym      221 non-null    int64
#  3   finance  221 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.0+ KB

# %%
df.month=pd.to_datetime(df.month)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    221 non-null    datetime64[ns]
#  1   diet     221 non-null    int64
#  2   gym      221 non-null    int64
#  3   finance  221 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 7.0 KB

# %%
#make the data index as month 
df.set_index(df.month, inplace =True)#the name of colums only

# %%
df.head()
# Out:
#                 month  diet  gym  finance
# month
# 2004-01-01 2004-01-01   100   25       47
# 2004-02-01 2004-02-01    73   21       46
# 2004-03-01 2004-03-01    66   21       41
# 2004-04-01 2004-04-01    68   19       44
# 2004-05-01 2004-05-01    71   19       43

# %% [markdown]
# # time series Analysis

# %% [markdown]
# # we have to do viz to time series analysis..

# %% [markdown]
# # viz data

# %%
df_.plot(figsize=(15,7));
df_=df.drop(["month"],axis=1)

# %%
#make a time series analys on diet
df.diet.plot(figsize=(15,10));

# %%
#make a time series analys on finance
df.finance.plot(figsize=(15,10));

# %%
#make a time series analys on gym
df.gym.plot(figsize=(20,10))

# %%
df.gym.rolling(12).mean().plot(figsize=(15,10));

# %% [markdown]
# # from sesone to trend

# %%
df.diet.rolling(12).mean().plot(figsize=(15,10));

# %%
df.finance.rolling(12).mean().plot(figsize=(15,10));

# %%
df_1=df.drop(["month","finance"],axis=1)
df_1.rolling(12).mean().plot(figsize=(15,10));

# %% [markdown]
# # انا كمحلل بيانات لازم افكر ازاى كانت سنه 2005 اكتر سنه دوروا فيها على الديت واقل مده على  الجيم  يبقى لازم ادور على الحل وهو انهم كانوا بيدوروا على الدايت لان حاجه حصلت تريند فى 2005 او كانوا بيدوا باستخدام الادويه يبقى لازم ادور على نوع ادويه او اغذيه واشوف العلاقه بينهم واوجد النتيجه
